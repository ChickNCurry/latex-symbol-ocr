# %%
import pandas as pd
import os
import cv2
import numpy as np
import torch

import torch_directml
dml = torch_directml.device()

path = "../../../data/archive/hasy-data-labels.csv"
basePath = "../../../data/archive/"

images = []
labels = []

df = pd.read_csv(path)

for i in df.index:
    img = cv2.imread(os.path.join(basePath, df.loc[i, "path"]))
    images.append(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
    labels.append(int(df.loc[i, "symbol_id"]))

images = torch.FloatTensor(np.array(images)[:, np.newaxis, :, :])
labels = torch.FloatTensor(np.array(labels))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.3, random_state=0)
X_train = X_train.to(dml)
X_test = X_test.to(dml)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

label_encoder = LabelEncoder()
onehot_encoder = OneHotEncoder(sparse_output = False)

labels_int = label_encoder.fit_transform(labels)
onehot_encoder.fit(labels_int.reshape(len(labels_int), 1))

y_train_int = torch.FloatTensor(label_encoder.transform(y_train))
y_train_onehot = torch.FloatTensor(onehot_encoder.transform(y_train_int.reshape(len(y_train_int), 1)))
y_test_int = torch.FloatTensor(label_encoder.transform(y_test))
y_test_onehot = torch.FloatTensor(onehot_encoder.transform(y_test_int.reshape(len(y_test_int), 1)))

y_train_int = y_train_int.to(dml)
y_test_int = y_test_int.to(dml)

num_of_classes = len(label_encoder.classes_)
input_shape = X_train[0].shape

print(num_of_classes)
print(input_shape)

np.save("classes.npy", label_encoder.classes_)
# Out:
# 369
# torch.Size([1, 32, 32])

# %%
import torch
import torch.nn as nn

class CNN(nn.Module):
    def __init__(self, in_channels, num_of_classes) -> None:
        super().__init__()

        self.model = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=32, kernel_size=5),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(in_features=64 * 5 * 5, out_features=1024),
            nn.LeakyReLU(),
            nn.Dropout(),
            nn.Linear(in_features=1024, out_features=1024),
            nn.LeakyReLU(),
            nn.Dropout(),
            nn.Linear(in_features=1024, out_features=1024),
            nn.LeakyReLU(),
            nn.Dropout(),
            nn.Linear(1024, num_of_classes)
        )

        # 1 * 32 * 32
        # 32 * 28 * 28
        # 32 * 14 * 14
        # 64 * 10 * 10
        # 64 * 5 * 5

        self.init_weights()

    def forward(self, x):
        return self.model(x)
    
    def init_weights(self):
        for m in self.model:
            if isinstance(m, nn.Conv2d):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

# %%
def get_accuracy(model, X, y):
    outputs = model(X)
    _, predicted = torch.max(outputs, 1)
    total_correct = (predicted == y).sum().item()
    total_samples = y.shape[0]
    accuracy = 100 * total_correct / total_samples
    return accuracy

# %%
model = CNN(1, num_of_classes).to(dml)

num_epochs = 40
batch_size = 1000
learning_rate = 0.001

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

train_accuracies = []
test_accuracies = []

for epoch in range(num_epochs):
    
    model.train()

    for i in range(0, len(X_train), batch_size):
    
        X_train_batch = X_train[i:(i + batch_size)].to(dml)
        y_train_onehot_batch = y_train_onehot[i:(i + batch_size)].to(dml) 
        y_train_int_batch = y_train_int[i:(i + batch_size)]

        # forward
        outputs = model(X_train_batch)
        loss = criterion(outputs, y_train_onehot_batch)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i / batch_size) % 20 == 0:
          print(f"epoch {epoch}, mini-batch {i / batch_size}/{len(X_train) / batch_size} loss is {loss.item()}")

    model.eval()

    # test_accuracy = get_accuracy(model, X_test, y_test_int)

    outputs = model(X_test[0:1000])
    _, predicted = torch.max(outputs, 1)
    total_correct = (predicted == y_test_int[0:1000]).sum().item()
    total_samples = y_test_int[0:1000].shape[0]
    test_accuracy = 100 * total_correct / total_samples
    test_accuracies.append(test_accuracy)

    outputs = model(X_train[0:1000])
    _, predicted = torch.max(outputs, 1)
    total_correct = (predicted == y_train_int[0:1000]).sum().item()
    total_samples = y_train_int[0:1000].shape[0]
    train_accuracy = 100 * total_correct / total_samples
    train_accuracies.append(train_accuracy)

    print(f"epoch {epoch}: train_accuracy is {train_accuracy}, test_accuracy is {test_accuracy}")
# Out:
# epoch 0, mini-batch 0.0/117.763 loss is 116.32728576660156
# epoch 0, mini-batch 20.0/117.763 loss is 5.622805118560791
# epoch 0, mini-batch 40.0/117.763 loss is 5.520845890045166
# epoch 0, mini-batch 60.0/117.763 loss is 5.367190361022949
# epoch 0, mini-batch 80.0/117.763 loss is 5.109365940093994
# epoch 0, mini-batch 100.0/117.763 loss is 4.810233116149902
# epoch 0: train_accuracy is 22.3, test_accuracy is 21.0
# epoch 1, mini-batch 0.0/117.763 loss is 4.476965427398682
# epoch 1, mini-batch 20.0/117.763 loss is 4.05513334274292
# epoch 1, mini-batch 40.0/117.763 loss is 3.8226795196533203
# epoch 1, mini-batch 60.0/117.763 loss is 3.5118300914764404
# epoch 1, mini-batch 80.0/117.763 loss is 3.1893463134765625
# epoch 1, mini-batch 100.0/117.763 loss is 3.084383726119995
# epoch 1: train_accuracy is 46.7, test_accuracy is 47.1
# epoch 2, mini-batch 0.0/117.763 loss is 2.9453797340393066
# epoch 2, mini-batch 20.0/117.763 loss is 2.838595390319824
# epoch 2, mini-batch 40.0/117.763 loss is 2.7216837406158447
# epoch 2, mini-batch 60.0/117.763 loss is 2.549330472946167
# epoch 2, mini-batch 80.0/117.763 loss is 2.412076234817505
# epoch 2, mini-batch 100.0/117.763 loss is 2.299504041671753
# epoch 2: train_accuracy is 57.3, test_accuracy is 56.8
# epoch 3, mini-batch 0.0/117.763 loss is 2.1856768131256104
# epoch 3, mini-batch 20.0/117.763 loss is 2.185828447341919
# epoch 3, mini-batch 40.0/117.763 loss is 2.1151070594787598
# epoch 3, mini-batch 60.0/117.763 loss is 1.9859035015106201
# epoch 3, mini-batch 80.0/117.763 loss is 1.875145673751831
# epoch 3, mini-batch 100.0/117.763 loss is 1.9234329462051392
# epoch 3: train_accuracy is 65.1, test_accuracy is 64.5
# epoch 4, mini-batch 0.0/117.763 loss is 1.737592339515686
# epoch 4, mini-batch 20.0/117.763 loss is 1.7401344776153564
# epoch 4, mini-batch 40.0/117.763 loss is 1.8129360675811768
# epoch 4, mini-batch 60.0/117.763 loss is 1.689849615097046
# epoch 4, mini-batch 80.0/117.763 loss is 1.62819242477417
# epoch 4, mini-batch 100.0/117.763 loss is 1.6316205263137817
# epoch 4: train_accuracy is 67.9, test_accuracy is 68.1
# epoch 5, mini-batch 0.0/117.763 loss is 1.5284143686294556
# epoch 5, mini-batch 20.0/117.763 loss is 1.5646079778671265
# epoch 5, mini-batch 40.0/117.763 loss is 1.5694090127944946
# epoch 5, mini-batch 60.0/117.763 loss is 1.4444143772125244
# epoch 5, mini-batch 80.0/117.763 loss is 1.4038269519805908
# epoch 5, mini-batch 100.0/117.763 loss is 1.4449259042739868
# epoch 5: train_accuracy is 70.6, test_accuracy is 69.6
# epoch 6, mini-batch 0.0/117.763 loss is 1.411133885383606
# epoch 6, mini-batch 20.0/117.763 loss is 1.3605079650878906
# epoch 6, mini-batch 40.0/117.763 loss is 1.4423025846481323
# epoch 6, mini-batch 60.0/117.763 loss is 1.3526270389556885
# epoch 6, mini-batch 80.0/117.763 loss is 1.3189280033111572
# epoch 6, mini-batch 100.0/117.763 loss is 1.3594475984573364
# epoch 6: train_accuracy is 73.4, test_accuracy is 71.2
# epoch 7, mini-batch 0.0/117.763 loss is 1.2129769325256348
# epoch 7, mini-batch 20.0/117.763 loss is 1.250084400177002
# epoch 7, mini-batch 40.0/117.763 loss is 1.3925451040267944
# epoch 7, mini-batch 60.0/117.763 loss is 1.2985804080963135
# epoch 7, mini-batch 80.0/117.763 loss is 1.2572789192199707
# epoch 7, mini-batch 100.0/117.763 loss is 1.1929247379302979
# epoch 7: train_accuracy is 75.6, test_accuracy is 72.4
# epoch 8, mini-batch 0.0/117.763 loss is 1.1711997985839844
# epoch 8, mini-batch 20.0/117.763 loss is 1.195029377937317
# epoch 8, mini-batch 40.0/117.763 loss is 1.2720937728881836
# epoch 8, mini-batch 60.0/117.763 loss is 1.1521015167236328
# epoch 8, mini-batch 80.0/117.763 loss is 1.2357999086380005
# epoch 8, mini-batch 100.0/117.763 loss is 1.2335084676742554
# epoch 8: train_accuracy is 75.7, test_accuracy is 73.6
# epoch 9, mini-batch 0.0/117.763 loss is 1.1121609210968018
# epoch 9, mini-batch 20.0/117.763 loss is 1.104785442352295
# epoch 9, mini-batch 40.0/117.763 loss is 1.2111272811889648
# epoch 9, mini-batch 60.0/117.763 loss is 1.1647752523422241
# epoch 9, mini-batch 80.0/117.763 loss is 1.0930372476577759
# epoch 9, mini-batch 100.0/117.763 loss is 1.1392295360565186
# epoch 9: train_accuracy is 77.4, test_accuracy is 73.1
# epoch 10, mini-batch 0.0/117.763 loss is 1.0781612396240234
# epoch 10, mini-batch 20.0/117.763 loss is 1.0388386249542236
# epoch 10, mini-batch 40.0/117.763 loss is 1.1692771911621094
# epoch 10, mini-batch 60.0/117.763 loss is 1.0343691110610962
# epoch 10, mini-batch 80.0/117.763 loss is 1.0877803564071655
# epoch 10, mini-batch 100.0/117.763 loss is 1.0871118307113647
# epoch 10: train_accuracy is 77.5, test_accuracy is 73.9
# epoch 11, mini-batch 0.0/117.763 loss is 1.002264380455017
# epoch 11, mini-batch 20.0/117.763 loss is 0.9988444447517395
# epoch 11, mini-batch 40.0/117.763 loss is 1.0353635549545288
# epoch 11, mini-batch 60.0/117.763 loss is 0.9798446297645569
# epoch 11, mini-batch 80.0/117.763 loss is 1.0055084228515625
# epoch 11, mini-batch 100.0/117.763 loss is 1.0633971691131592
# epoch 11: train_accuracy is 78.9, test_accuracy is 73.7
# epoch 12, mini-batch 0.0/117.763 loss is 0.9501927495002747
# epoch 12, mini-batch 20.0/117.763 loss is 0.959068775177002
# epoch 12, mini-batch 40.0/117.763 loss is 1.0384758710861206
# epoch 12, mini-batch 60.0/117.763 loss is 0.9935743808746338
# epoch 12, mini-batch 80.0/117.763 loss is 0.9077472686767578
# epoch 12, mini-batch 100.0/117.763 loss is 1.032853364944458
# epoch 12: train_accuracy is 79.5, test_accuracy is 74.4
# epoch 13, mini-batch 0.0/117.763 loss is 0.8949990272521973
# epoch 13, mini-batch 20.0/117.763 loss is 0.954511821269989
# epoch 13, mini-batch 40.0/117.763 loss is 0.9297420978546143
# epoch 13, mini-batch 60.0/117.763 loss is 0.9582366943359375
# epoch 13, mini-batch 80.0/117.763 loss is 0.870552659034729
# epoch 13, mini-batch 100.0/117.763 loss is 0.9344147443771362
# epoch 13: train_accuracy is 79.7, test_accuracy is 76.1
# epoch 14, mini-batch 0.0/117.763 loss is 0.8672775030136108
# epoch 14, mini-batch 20.0/117.763 loss is 0.9034568667411804
# epoch 14, mini-batch 40.0/117.763 loss is 0.9137759208679199
# epoch 14, mini-batch 60.0/117.763 loss is 0.8824754953384399
# epoch 14, mini-batch 80.0/117.763 loss is 0.8608109354972839
# epoch 14, mini-batch 100.0/117.763 loss is 0.9458829164505005
# epoch 14: train_accuracy is 79.9, test_accuracy is 76.4
# epoch 15, mini-batch 0.0/117.763 loss is 0.8905770182609558
# epoch 15, mini-batch 20.0/117.763 loss is 0.8981821537017822
# epoch 15, mini-batch 40.0/117.763 loss is 0.9212860465049744
# epoch 15, mini-batch 60.0/117.763 loss is 0.8955427408218384
# epoch 15, mini-batch 80.0/117.763 loss is 0.8423261046409607
# epoch 15, mini-batch 100.0/117.763 loss is 0.9015688896179199
# epoch 15: train_accuracy is 81.1, test_accuracy is 75.7
# epoch 16, mini-batch 0.0/117.763 loss is 0.8051490187644958
# epoch 16, mini-batch 20.0/117.763 loss is 0.8717581629753113
# epoch 16, mini-batch 40.0/117.763 loss is 0.8320235013961792
# epoch 16, mini-batch 60.0/117.763 loss is 0.854667067527771
# epoch 16, mini-batch 80.0/117.763 loss is 0.8173912763595581
# epoch 16, mini-batch 100.0/117.763 loss is 0.8772512674331665
# epoch 16: train_accuracy is 80.2, test_accuracy is 75.6
# epoch 17, mini-batch 0.0/117.763 loss is 0.7807245850563049
# epoch 17, mini-batch 20.0/117.763 loss is 0.7737099528312683
# epoch 17, mini-batch 40.0/117.763 loss is 0.8752148151397705
# epoch 17, mini-batch 60.0/117.763 loss is 0.7920416593551636
# epoch 17, mini-batch 80.0/117.763 loss is 0.7697983980178833
# epoch 17, mini-batch 100.0/117.763 loss is 0.894045889377594
# epoch 17: train_accuracy is 82.0, test_accuracy is 77.2
# epoch 18, mini-batch 0.0/117.763 loss is 0.7958572506904602
# epoch 18, mini-batch 20.0/117.763 loss is 0.7679116129875183
# epoch 18, mini-batch 40.0/117.763 loss is 0.8665961027145386
# epoch 18, mini-batch 60.0/117.763 loss is 0.8145583868026733
# epoch 18, mini-batch 80.0/117.763 loss is 0.7541342973709106
# epoch 18, mini-batch 100.0/117.763 loss is 0.795306921005249
# epoch 18: train_accuracy is 82.2, test_accuracy is 76.3
# epoch 19, mini-batch 0.0/117.763 loss is 0.8039343357086182
# epoch 19, mini-batch 20.0/117.763 loss is 0.7754486799240112
# epoch 19, mini-batch 40.0/117.763 loss is 0.8371638655662537
# epoch 19, mini-batch 60.0/117.763 loss is 0.7959852814674377
# epoch 19, mini-batch 80.0/117.763 loss is 0.7609459757804871
# epoch 19, mini-batch 100.0/117.763 loss is 0.7849857211112976
# epoch 19: train_accuracy is 81.7, test_accuracy is 76.9
# epoch 20, mini-batch 0.0/117.763 loss is 0.7254002094268799
# epoch 20, mini-batch 20.0/117.763 loss is 0.7526326179504395
# epoch 20, mini-batch 40.0/117.763 loss is 0.7685182094573975
# epoch 20, mini-batch 60.0/117.763 loss is 0.780709981918335
# epoch 20, mini-batch 80.0/117.763 loss is 0.7614749073982239
# epoch 20, mini-batch 100.0/117.763 loss is 0.8043918609619141
# epoch 20: train_accuracy is 81.8, test_accuracy is 76.1
# epoch 21, mini-batch 0.0/117.763 loss is 0.7730470299720764
# epoch 21, mini-batch 20.0/117.763 loss is 0.7386781573295593
# epoch 21, mini-batch 40.0/117.763 loss is 0.818611741065979
# epoch 21, mini-batch 60.0/117.763 loss is 0.7361729145050049
# epoch 21, mini-batch 80.0/117.763 loss is 0.7718335390090942
# epoch 21, mini-batch 100.0/117.763 loss is 0.8007539510726929
# epoch 21: train_accuracy is 83.2, test_accuracy is 76.4
# epoch 22, mini-batch 0.0/117.763 loss is 0.6776666045188904
# epoch 22, mini-batch 20.0/117.763 loss is 0.7385370135307312
# epoch 22, mini-batch 40.0/117.763 loss is 0.7959276437759399
# epoch 22, mini-batch 60.0/117.763 loss is 0.760610044002533
# epoch 22, mini-batch 80.0/117.763 loss is 0.7304324507713318
# epoch 22, mini-batch 100.0/117.763 loss is 0.7607992887496948
# epoch 22: train_accuracy is 82.8, test_accuracy is 76.1
# epoch 23, mini-batch 0.0/117.763 loss is 0.6975573897361755
# epoch 23, mini-batch 20.0/117.763 loss is 0.6891825199127197
# epoch 23, mini-batch 40.0/117.763 loss is 0.7246784567832947
# epoch 23, mini-batch 60.0/117.763 loss is 0.7400627136230469
# epoch 23, mini-batch 80.0/117.763 loss is 0.6782339215278625
# epoch 23, mini-batch 100.0/117.763 loss is 0.7947542071342468
# epoch 23: train_accuracy is 83.7, test_accuracy is 76.5
# epoch 24, mini-batch 0.0/117.763 loss is 0.6748897433280945
# epoch 24, mini-batch 20.0/117.763 loss is 0.687613308429718
# epoch 24, mini-batch 40.0/117.763 loss is 0.7171648144721985
# epoch 24, mini-batch 60.0/117.763 loss is 0.7540989518165588
# epoch 24, mini-batch 80.0/117.763 loss is 0.687500536441803
# epoch 24, mini-batch 100.0/117.763 loss is 0.7359262108802795
# epoch 24: train_accuracy is 83.9, test_accuracy is 76.0
# epoch 25, mini-batch 0.0/117.763 loss is 0.6690305471420288
# epoch 25, mini-batch 20.0/117.763 loss is 0.7124626636505127
# epoch 25, mini-batch 40.0/117.763 loss is 0.7301769256591797
# epoch 25, mini-batch 60.0/117.763 loss is 0.7306117415428162
# epoch 25, mini-batch 80.0/117.763 loss is 0.6704299449920654
# epoch 25, mini-batch 100.0/117.763 loss is 0.7365261316299438
# epoch 25: train_accuracy is 83.4, test_accuracy is 76.8
# epoch 26, mini-batch 0.0/117.763 loss is 0.6452672481536865
# epoch 26, mini-batch 20.0/117.763 loss is 0.6950487494468689
# epoch 26, mini-batch 40.0/117.763 loss is 0.6894625425338745
# epoch 26, mini-batch 60.0/117.763 loss is 0.6593910455703735
# epoch 26, mini-batch 80.0/117.763 loss is 0.6815552711486816
# epoch 26, mini-batch 100.0/117.763 loss is 0.6826726198196411
# epoch 26: train_accuracy is 84.4, test_accuracy is 76.6
# epoch 27, mini-batch 0.0/117.763 loss is 0.6859625577926636
# epoch 27, mini-batch 20.0/117.763 loss is 0.679179310798645
# epoch 27, mini-batch 40.0/117.763 loss is 0.6958062052726746
# epoch 27, mini-batch 60.0/117.763 loss is 0.7307258248329163
# epoch 27, mini-batch 80.0/117.763 loss is 0.6582351922988892
# epoch 27, mini-batch 100.0/117.763 loss is 0.6850338578224182
# epoch 27: train_accuracy is 84.4, test_accuracy is 76.6
# epoch 28, mini-batch 0.0/117.763 loss is 0.6269089579582214
# epoch 28, mini-batch 20.0/117.763 loss is 0.6655005812644958
# epoch 28, mini-batch 40.0/117.763 loss is 0.7071256637573242
# epoch 28, mini-batch 60.0/117.763 loss is 0.7325987219810486
# epoch 28, mini-batch 80.0/117.763 loss is 0.7175483703613281
# epoch 28, mini-batch 100.0/117.763 loss is 0.672963559627533
# epoch 28: train_accuracy is 84.5, test_accuracy is 77.5
# epoch 29, mini-batch 0.0/117.763 loss is 0.6579872369766235
# epoch 29, mini-batch 20.0/117.763 loss is 0.6757798194885254
# epoch 29, mini-batch 40.0/117.763 loss is 0.6547662615776062
# epoch 29, mini-batch 60.0/117.763 loss is 0.6798463463783264
# epoch 29, mini-batch 80.0/117.763 loss is 0.6275943517684937
# epoch 29, mini-batch 100.0/117.763 loss is 0.6578264832496643
# epoch 29: train_accuracy is 84.8, test_accuracy is 77.6
# epoch 30, mini-batch 0.0/117.763 loss is 0.6309546828269958
# epoch 30, mini-batch 20.0/117.763 loss is 0.6989951729774475
# epoch 30, mini-batch 40.0/117.763 loss is 0.6962831020355225
# epoch 30, mini-batch 60.0/117.763 loss is 0.6703978776931763
# epoch 30, mini-batch 80.0/117.763 loss is 0.6389416456222534
# epoch 30, mini-batch 100.0/117.763 loss is 0.6549803614616394
# epoch 30: train_accuracy is 85.6, test_accuracy is 77.9
# epoch 31, mini-batch 0.0/117.763 loss is 0.5971567630767822
# epoch 31, mini-batch 20.0/117.763 loss is 0.6051580309867859
# epoch 31, mini-batch 40.0/117.763 loss is 0.657581090927124
# epoch 31, mini-batch 60.0/117.763 loss is 0.6748915314674377
# epoch 31, mini-batch 80.0/117.763 loss is 0.6374384164810181
# epoch 31, mini-batch 100.0/117.763 loss is 0.6467474102973938
# epoch 31: train_accuracy is 85.1, test_accuracy is 76.4
# epoch 32, mini-batch 0.0/117.763 loss is 0.6325896978378296
# epoch 32, mini-batch 20.0/117.763 loss is 0.6096680760383606
# epoch 32, mini-batch 40.0/117.763 loss is 0.6449061632156372
# epoch 32, mini-batch 60.0/117.763 loss is 0.6151298880577087
# epoch 32, mini-batch 80.0/117.763 loss is 0.6583542823791504
# epoch 32, mini-batch 100.0/117.763 loss is 0.6812615394592285
# epoch 32: train_accuracy is 86.4, test_accuracy is 76.6
# epoch 33, mini-batch 0.0/117.763 loss is 0.6169626712799072
# epoch 33, mini-batch 20.0/117.763 loss is 0.5583844780921936
# epoch 33, mini-batch 40.0/117.763 loss is 0.6607053279876709
# epoch 33, mini-batch 60.0/117.763 loss is 0.6095211505889893
# epoch 33, mini-batch 80.0/117.763 loss is 0.6331709027290344
# epoch 33, mini-batch 100.0/117.763 loss is 0.6237986087799072
# epoch 33: train_accuracy is 85.6, test_accuracy is 77.0
# epoch 34, mini-batch 0.0/117.763 loss is 0.5912851691246033
# epoch 34, mini-batch 20.0/117.763 loss is 0.5819119215011597
# epoch 34, mini-batch 40.0/117.763 loss is 0.6492366790771484
# epoch 34, mini-batch 60.0/117.763 loss is 0.6237022876739502
# epoch 34, mini-batch 80.0/117.763 loss is 0.5369424223899841
# epoch 34, mini-batch 100.0/117.763 loss is 0.6510981321334839
# epoch 34: train_accuracy is 85.8, test_accuracy is 76.5
# epoch 35, mini-batch 0.0/117.763 loss is 0.6482953429222107
# epoch 35, mini-batch 20.0/117.763 loss is 0.5875531435012817
# epoch 35, mini-batch 40.0/117.763 loss is 0.642932653427124
# epoch 35, mini-batch 60.0/117.763 loss is 0.5901407599449158
# epoch 35, mini-batch 80.0/117.763 loss is 0.602540135383606
# epoch 35, mini-batch 100.0/117.763 loss is 0.6199135780334473
# epoch 35: train_accuracy is 85.8, test_accuracy is 76.2
# epoch 36, mini-batch 0.0/117.763 loss is 0.6075764298439026
# epoch 36, mini-batch 20.0/117.763 loss is 0.5695183277130127
# epoch 36, mini-batch 40.0/117.763 loss is 0.5834195613861084
# epoch 36, mini-batch 60.0/117.763 loss is 0.5630415081977844
# epoch 36, mini-batch 80.0/117.763 loss is 0.55876225233078
# epoch 36, mini-batch 100.0/117.763 loss is 0.6208146214485168
# epoch 36: train_accuracy is 85.6, test_accuracy is 77.2
# epoch 37, mini-batch 0.0/117.763 loss is 0.6336272954940796
# epoch 37, mini-batch 20.0/117.763 loss is 0.5509358048439026
# epoch 37, mini-batch 40.0/117.763 loss is 0.6043485403060913
# epoch 37, mini-batch 60.0/117.763 loss is 0.6075901389122009
# epoch 37, mini-batch 80.0/117.763 loss is 0.5557593107223511
# epoch 37, mini-batch 100.0/117.763 loss is 0.6125547289848328
# epoch 37: train_accuracy is 85.4, test_accuracy is 76.8
# epoch 38, mini-batch 0.0/117.763 loss is 0.5946926474571228
# epoch 38, mini-batch 20.0/117.763 loss is 0.6544878482818604
# epoch 38, mini-batch 40.0/117.763 loss is 0.5843420624732971
# epoch 38, mini-batch 60.0/117.763 loss is 0.5588160157203674
# epoch 38, mini-batch 80.0/117.763 loss is 0.5537745952606201
# epoch 38, mini-batch 100.0/117.763 loss is 0.5878088474273682
# epoch 38: train_accuracy is 86.2, test_accuracy is 76.3
# epoch 39, mini-batch 0.0/117.763 loss is 0.5752620100975037
# epoch 39, mini-batch 20.0/117.763 loss is 0.5899640917778015
# epoch 39, mini-batch 40.0/117.763 loss is 0.6078130602836609
# epoch 39, mini-batch 60.0/117.763 loss is 0.5975099802017212
# epoch 39, mini-batch 80.0/117.763 loss is 0.5185191035270691
# epoch 39, mini-batch 100.0/117.763 loss is 0.6516921520233154
# epoch 39: train_accuracy is 87.3, test_accuracy is 76.5

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(range(num_epochs), train_accuracies, label="train")
ax.plot(range(num_epochs), test_accuracies, label="test")
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy per Epoch')
ax.legend()
plt.show()

# %%
out = model(X_test[76][None, :, :, :])
_, predicted = torch.max(out, 1)
print(predicted)
print(y_test_int[76])
# Out:
# tensor([289], device='privateuseone:0')
# tensor(289., device='privateuseone:0')

# %%
from torch import save

model = model.to("cpu")
with open('model_state.pt', 'wb') as f: 
        save(model.state_dict(), f)

# %%
from torch import load

with open('model_state.pt', 'rb') as f: 
        model.load_state_dict(load(f))
