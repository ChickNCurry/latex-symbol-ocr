# %%
import pandas as pd
import os
import cv2
import numpy as np
import torch

# %%
import torch_directml
dml = torch_directml.device()
dml
# Out:
# device(type='privateuseone', index=0)

# %%
data_path = "../data/archive/hasy-data-labels.csv"
base_path = "../data/archive/"

images = []
labels = []

df = pd.read_csv(data_path)

for i in df.index:
    img_path = os.path.join(base_path, str(df.loc[i, "path"]))

    if not os.path.exists(img_path):
        continue

    img = cv2.imread(img_path)

    if img is None:
        continue
    
    grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    images.append(grey_img)
    
    label = df.loc[i, "symbol_id"]
    labels.append(label)

images = torch.FloatTensor(np.array(images)[:, np.newaxis, :, :])
labels = torch.FloatTensor(np.array(labels))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.3, random_state=0)
X_train = X_train.to(dml)
X_test = X_test.to(dml)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

label_encoder = LabelEncoder()
onehot_encoder = OneHotEncoder(sparse_output = False)

labels_int = label_encoder.fit_transform(labels)
onehot_encoder.fit(np.reshape(labels_int, (len(labels), 1)))

y_train_int = torch.FloatTensor(label_encoder.transform(y_train))
y_train_onehot = torch.FloatTensor(onehot_encoder.transform(np.reshape(y_train_int, (len(y_train_int), 1))))
y_test_int = torch.FloatTensor(label_encoder.transform(y_test))
y_test_onehot = torch.FloatTensor(onehot_encoder.transform(np.reshape(y_test_int, (len(y_test_int), 1))))

y_train_int = y_train_int.to(dml)
y_test_int = y_test_int.to(dml)

num_of_classes = len(label_encoder.classes_)
input_shape = X_train[0].shape

print(num_of_classes)
print(input_shape)

np.save("classes.npy", label_encoder.classes_)
# Out:
# 369
# torch.Size([1, 32, 32])

# %%
import torch
import torch.nn as nn

class CNN(nn.Module):
    def __init__(self, in_channels, num_of_classes) -> None:
        super().__init__()

        self.model = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=32, kernel_size=5),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(in_features=64 * 5 * 5, out_features=1024),
            nn.LeakyReLU(),
            nn.Dropout(),
            nn.Linear(in_features=1024, out_features=1024),
            nn.LeakyReLU(),
            nn.Dropout(),
            nn.Linear(in_features=1024, out_features=1024),
            nn.LeakyReLU(),
            nn.Dropout(),
            nn.Linear(1024, num_of_classes)
        )

        # 1 * 32 * 32
        # 32 * 28 * 28
        # 32 * 14 * 14
        # 64 * 10 * 10
        # 64 * 5 * 5

        self.init_weights()

    def forward(self, x):
        return self.model(x)
    
    def init_weights(self):
        for m in self.model:
            if isinstance(m, nn.Conv2d):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)

# %%
def get_accuracy(model, X, y):
    outputs = model(X)
    _, predicted = torch.max(outputs, 1)
    total_correct = (predicted == y).sum().item()
    total_samples = y.shape[0]
    accuracy = 100 * total_correct / total_samples
    return accuracy

# %%
model = CNN(1, num_of_classes).to(dml)

num_epochs = 40
batch_size = 1000
learning_rate = 0.001

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)

train_accuracies = []
test_accuracies = []

for epoch in range(num_epochs):
    
    model.train()

    for i in range(0, len(X_train), batch_size):
    
        X_train_batch = X_train[i:(i + batch_size)].to(dml)
        y_train_onehot_batch = y_train_onehot[i:(i + batch_size)].to(dml) 
        y_train_int_batch = y_train_int[i:(i + batch_size)]

        # forward
        outputs = model(X_train_batch)
        loss = criterion(outputs, y_train_onehot_batch)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i / batch_size) % 20 == 0:
          print(f"epoch {epoch}, mini-batch {i / batch_size}/{len(X_train) / batch_size} loss is {loss.item()}")

    model.eval()

    # test_accuracy = get_accuracy(model, X_test, y_test_int)

    outputs = model(X_test[0:1000])
    _, predicted = torch.max(outputs, 1)
    total_correct = (predicted == y_test_int[0:1000]).sum().item()
    total_samples = y_test_int[0:1000].shape[0]
    test_accuracy = 100 * total_correct / total_samples
    test_accuracies.append(test_accuracy)

    outputs = model(X_train[0:1000])
    _, predicted = torch.max(outputs, 1)
    total_correct = (predicted == y_train_int[0:1000]).sum().item()
    total_samples = y_train_int[0:1000].shape[0]
    train_accuracy = 100 * total_correct / total_samples
    train_accuracies.append(train_accuracy)

    print(f"epoch {epoch}: train_accuracy is {train_accuracy}, test_accuracy is {test_accuracy}")
# Out:
# epoch 0, mini-batch 0.0/117.506 loss is 118.46453857421875
# epoch 0, mini-batch 20.0/117.506 loss is 5.648243427276611
# epoch 0, mini-batch 40.0/117.506 loss is 5.546192646026611
# epoch 0, mini-batch 60.0/117.506 loss is 5.47504997253418
# epoch 0, mini-batch 80.0/117.506 loss is 5.474151611328125
# epoch 0, mini-batch 100.0/117.506 loss is 5.428908348083496
# epoch 0: train_accuracy is 1.6, test_accuracy is 1.4
# epoch 1, mini-batch 0.0/117.506 loss is 5.417917251586914
# epoch 1, mini-batch 20.0/117.506 loss is 5.286795139312744
# epoch 1, mini-batch 40.0/117.506 loss is 5.089631080627441
# epoch 1, mini-batch 60.0/117.506 loss is 4.760851860046387
# epoch 1, mini-batch 80.0/117.506 loss is 4.392483711242676
# epoch 1, mini-batch 100.0/117.506 loss is 3.9731638431549072
# epoch 1: train_accuracy is 34.3, test_accuracy is 32.3
# epoch 2, mini-batch 0.0/117.506 loss is 3.642746925354004
# epoch 2, mini-batch 20.0/117.506 loss is 3.390794515609741
# epoch 2, mini-batch 40.0/117.506 loss is 3.0495762825012207
# epoch 2, mini-batch 60.0/117.506 loss is 2.825775384902954
# epoch 2, mini-batch 80.0/117.506 loss is 2.708585262298584
# epoch 2, mini-batch 100.0/117.506 loss is 2.674635648727417
# epoch 2: train_accuracy is 54.3, test_accuracy is 54.9
# epoch 3, mini-batch 0.0/117.506 loss is 2.438870668411255
# epoch 3, mini-batch 20.0/117.506 loss is 2.470726251602173
# epoch 3, mini-batch 40.0/117.506 loss is 2.2121496200561523
# epoch 3, mini-batch 60.0/117.506 loss is 2.0645389556884766
# epoch 3, mini-batch 80.0/117.506 loss is 2.0580921173095703
# epoch 3, mini-batch 100.0/117.506 loss is 1.9765870571136475
# epoch 3: train_accuracy is 65.1, test_accuracy is 63.5
# epoch 4, mini-batch 0.0/117.506 loss is 1.9708374738693237
# epoch 4, mini-batch 20.0/117.506 loss is 1.9014700651168823
# epoch 4, mini-batch 40.0/117.506 loss is 1.7886725664138794
# epoch 4, mini-batch 60.0/117.506 loss is 1.6369397640228271
# epoch 4, mini-batch 80.0/117.506 loss is 1.734889268875122
# epoch 4, mini-batch 100.0/117.506 loss is 1.6888118982315063
# epoch 4: train_accuracy is 69.2, test_accuracy is 67.9
# epoch 5, mini-batch 0.0/117.506 loss is 1.693585753440857
# epoch 5, mini-batch 20.0/117.506 loss is 1.7059584856033325
# epoch 5, mini-batch 40.0/117.506 loss is 1.5509124994277954
# epoch 5, mini-batch 60.0/117.506 loss is 1.5480506420135498
# epoch 5, mini-batch 80.0/117.506 loss is 1.4819883108139038
# epoch 5, mini-batch 100.0/117.506 loss is 1.4265663623809814
# epoch 5: train_accuracy is 72.0, test_accuracy is 72.3
# epoch 6, mini-batch 0.0/117.506 loss is 1.4784246683120728
# epoch 6, mini-batch 20.0/117.506 loss is 1.4895343780517578
# epoch 6, mini-batch 40.0/117.506 loss is 1.3759851455688477
# epoch 6, mini-batch 60.0/117.506 loss is 1.2414458990097046
# epoch 6, mini-batch 80.0/117.506 loss is 1.2647392749786377
# epoch 6, mini-batch 100.0/117.506 loss is 1.3273752927780151
# epoch 6: train_accuracy is 73.4, test_accuracy is 73.5
# epoch 7, mini-batch 0.0/117.506 loss is 1.3579233884811401
# epoch 7, mini-batch 20.0/117.506 loss is 1.334478735923767
# epoch 7, mini-batch 40.0/117.506 loss is 1.2124537229537964
# epoch 7, mini-batch 60.0/117.506 loss is 1.1635581254959106
# epoch 7, mini-batch 80.0/117.506 loss is 1.1675910949707031
# epoch 7, mini-batch 100.0/117.506 loss is 1.211963415145874
# epoch 7: train_accuracy is 74.5, test_accuracy is 75.8
# epoch 8, mini-batch 0.0/117.506 loss is 1.2564924955368042
# epoch 8, mini-batch 20.0/117.506 loss is 1.2038111686706543
# epoch 8, mini-batch 40.0/117.506 loss is 1.1046597957611084
# epoch 8, mini-batch 60.0/117.506 loss is 1.0363942384719849
# epoch 8, mini-batch 80.0/117.506 loss is 1.107364535331726
# epoch 8, mini-batch 100.0/117.506 loss is 1.1194236278533936
# epoch 8: train_accuracy is 77.6, test_accuracy is 75.8
# epoch 9, mini-batch 0.0/117.506 loss is 1.1725475788116455
# epoch 9, mini-batch 20.0/117.506 loss is 1.110169529914856
# epoch 9, mini-batch 40.0/117.506 loss is 1.0625197887420654
# epoch 9, mini-batch 60.0/117.506 loss is 0.9739015698432922
# epoch 9, mini-batch 80.0/117.506 loss is 1.052194595336914
# epoch 9, mini-batch 100.0/117.506 loss is 1.1248184442520142
# epoch 9: train_accuracy is 76.5, test_accuracy is 76.6
# epoch 10, mini-batch 0.0/117.506 loss is 1.144906759262085
# epoch 10, mini-batch 20.0/117.506 loss is 1.0699044466018677
# epoch 10, mini-batch 40.0/117.506 loss is 0.9918994903564453
# epoch 10, mini-batch 60.0/117.506 loss is 0.9485132694244385
# epoch 10, mini-batch 80.0/117.506 loss is 0.9775751829147339
# epoch 10, mini-batch 100.0/117.506 loss is 1.0216954946517944
# epoch 10: train_accuracy is 78.5, test_accuracy is 77.6
# epoch 11, mini-batch 0.0/117.506 loss is 1.1082481145858765
# epoch 11, mini-batch 20.0/117.506 loss is 0.9717888236045837
# epoch 11, mini-batch 40.0/117.506 loss is 0.8701926469802856
# epoch 11, mini-batch 60.0/117.506 loss is 0.8876104950904846
# epoch 11, mini-batch 80.0/117.506 loss is 0.9076563119888306
# epoch 11, mini-batch 100.0/117.506 loss is 1.018286108970642
# epoch 11: train_accuracy is 80.1, test_accuracy is 77.6
# epoch 12, mini-batch 0.0/117.506 loss is 1.0524044036865234
# epoch 12, mini-batch 20.0/117.506 loss is 1.0012115240097046
# epoch 12, mini-batch 40.0/117.506 loss is 0.9202510118484497
# epoch 12, mini-batch 60.0/117.506 loss is 0.8635327816009521
# epoch 12, mini-batch 80.0/117.506 loss is 0.8648393750190735
# epoch 12, mini-batch 100.0/117.506 loss is 0.9585294127464294
# epoch 12: train_accuracy is 79.4, test_accuracy is 77.9
# epoch 13, mini-batch 0.0/117.506 loss is 1.0322901010513306
# epoch 13, mini-batch 20.0/117.506 loss is 0.9132936000823975
# epoch 13, mini-batch 40.0/117.506 loss is 0.8447792530059814
# epoch 13, mini-batch 60.0/117.506 loss is 0.8237040638923645
# epoch 13, mini-batch 80.0/117.506 loss is 0.8760573863983154
# epoch 13, mini-batch 100.0/117.506 loss is 0.8740915656089783
# epoch 13: train_accuracy is 81.1, test_accuracy is 78.4
# epoch 14, mini-batch 0.0/117.506 loss is 0.9300440549850464
# epoch 14, mini-batch 20.0/117.506 loss is 0.9368829727172852
# epoch 14, mini-batch 40.0/117.506 loss is 0.8533838987350464
# epoch 14, mini-batch 60.0/117.506 loss is 0.7742237448692322
# epoch 14, mini-batch 80.0/117.506 loss is 0.8523847460746765
# epoch 14, mini-batch 100.0/117.506 loss is 0.8525536060333252
# epoch 14: train_accuracy is 81.5, test_accuracy is 79.3
# epoch 15, mini-batch 0.0/117.506 loss is 0.9147467613220215
# epoch 15, mini-batch 20.0/117.506 loss is 0.8938046097755432
# epoch 15, mini-batch 40.0/117.506 loss is 0.7724839448928833
# epoch 15, mini-batch 60.0/117.506 loss is 0.7333264946937561
# epoch 15, mini-batch 80.0/117.506 loss is 0.8039299845695496
# epoch 15, mini-batch 100.0/117.506 loss is 0.8683933615684509
# epoch 15: train_accuracy is 82.9, test_accuracy is 79.3
# epoch 16, mini-batch 0.0/117.506 loss is 0.8784604668617249
# epoch 16, mini-batch 20.0/117.506 loss is 0.8167468905448914
# epoch 16, mini-batch 40.0/117.506 loss is 0.8012945652008057
# epoch 16, mini-batch 60.0/117.506 loss is 0.714543879032135
# epoch 16, mini-batch 80.0/117.506 loss is 0.7463777661323547
# epoch 16, mini-batch 100.0/117.506 loss is 0.8768212199211121
# epoch 16: train_accuracy is 83.2, test_accuracy is 79.9
# epoch 17, mini-batch 0.0/117.506 loss is 0.7930386066436768
# epoch 17, mini-batch 20.0/117.506 loss is 0.8357838988304138
# epoch 17, mini-batch 40.0/117.506 loss is 0.7599121332168579
# epoch 17, mini-batch 60.0/117.506 loss is 0.7077366709709167
# epoch 17, mini-batch 80.0/117.506 loss is 0.75565505027771
# epoch 17, mini-batch 100.0/117.506 loss is 0.7718308568000793
# epoch 17: train_accuracy is 82.7, test_accuracy is 80.4
# epoch 18, mini-batch 0.0/117.506 loss is 0.8138116598129272
# epoch 18, mini-batch 20.0/117.506 loss is 0.8036614060401917
# epoch 18, mini-batch 40.0/117.506 loss is 0.757326066493988
# epoch 18, mini-batch 60.0/117.506 loss is 0.6863929629325867
# epoch 18, mini-batch 80.0/117.506 loss is 0.7480058670043945
# epoch 18, mini-batch 100.0/117.506 loss is 0.8294907212257385
# epoch 18: train_accuracy is 83.8, test_accuracy is 80.4
# epoch 19, mini-batch 0.0/117.506 loss is 0.8282862305641174
# epoch 19, mini-batch 20.0/117.506 loss is 0.7893558740615845
# epoch 19, mini-batch 40.0/117.506 loss is 0.7427656650543213
# epoch 19, mini-batch 60.0/117.506 loss is 0.6582213044166565
# epoch 19, mini-batch 80.0/117.506 loss is 0.7124053239822388
# epoch 19, mini-batch 100.0/117.506 loss is 0.798237144947052
# epoch 19: train_accuracy is 84.0, test_accuracy is 80.1
# epoch 20, mini-batch 0.0/117.506 loss is 0.7656049132347107
# epoch 20, mini-batch 20.0/117.506 loss is 0.7431665658950806
# epoch 20, mini-batch 40.0/117.506 loss is 0.6859185099601746
# epoch 20, mini-batch 60.0/117.506 loss is 0.6629135012626648
# epoch 20, mini-batch 80.0/117.506 loss is 0.6960417628288269
# epoch 20, mini-batch 100.0/117.506 loss is 0.7030803561210632
# epoch 20: train_accuracy is 84.3, test_accuracy is 80.8
# epoch 21, mini-batch 0.0/117.506 loss is 0.7434855103492737
# epoch 21, mini-batch 20.0/117.506 loss is 0.7653604745864868
# epoch 21, mini-batch 40.0/117.506 loss is 0.6778778433799744
# epoch 21, mini-batch 60.0/117.506 loss is 0.6506355404853821
# epoch 21, mini-batch 80.0/117.506 loss is 0.6949930191040039
# epoch 21, mini-batch 100.0/117.506 loss is 0.7494951486587524
# epoch 21: train_accuracy is 85.1, test_accuracy is 80.8
# epoch 22, mini-batch 0.0/117.506 loss is 0.7833110690116882
# epoch 22, mini-batch 20.0/117.506 loss is 0.7447102665901184
# epoch 22, mini-batch 40.0/117.506 loss is 0.7086692452430725
# epoch 22, mini-batch 60.0/117.506 loss is 0.6460916996002197
# epoch 22, mini-batch 80.0/117.506 loss is 0.700227677822113
# epoch 22, mini-batch 100.0/117.506 loss is 0.7173569202423096
# epoch 22: train_accuracy is 84.6, test_accuracy is 80.6
# epoch 23, mini-batch 0.0/117.506 loss is 0.7401965856552124
# epoch 23, mini-batch 20.0/117.506 loss is 0.6932414770126343
# epoch 23, mini-batch 40.0/117.506 loss is 0.628273069858551
# epoch 23, mini-batch 60.0/117.506 loss is 0.6354427933692932
# epoch 23, mini-batch 80.0/117.506 loss is 0.6732532382011414
# epoch 23, mini-batch 100.0/117.506 loss is 0.7016305327415466
# epoch 23: train_accuracy is 85.1, test_accuracy is 80.4
# epoch 24, mini-batch 0.0/117.506 loss is 0.7500218749046326
# epoch 24, mini-batch 20.0/117.506 loss is 0.7578214406967163
# epoch 24, mini-batch 40.0/117.506 loss is 0.6454258561134338
# epoch 24, mini-batch 60.0/117.506 loss is 0.6164030432701111
# epoch 24, mini-batch 80.0/117.506 loss is 0.6734586358070374
# epoch 24, mini-batch 100.0/117.506 loss is 0.6991643905639648
# epoch 24: train_accuracy is 84.6, test_accuracy is 81.5
# epoch 25, mini-batch 0.0/117.506 loss is 0.748352587223053
# epoch 25, mini-batch 20.0/117.506 loss is 0.7017911672592163
# epoch 25, mini-batch 40.0/117.506 loss is 0.6843236088752747
# epoch 25, mini-batch 60.0/117.506 loss is 0.60673987865448
# epoch 25, mini-batch 80.0/117.506 loss is 0.6138831377029419
# epoch 25, mini-batch 100.0/117.506 loss is 0.683488667011261
# epoch 25: train_accuracy is 85.4, test_accuracy is 80.9
# epoch 26, mini-batch 0.0/117.506 loss is 0.7139519453048706
# epoch 26, mini-batch 20.0/117.506 loss is 0.758966326713562
# epoch 26, mini-batch 40.0/117.506 loss is 0.6548408269882202
# epoch 26, mini-batch 60.0/117.506 loss is 0.5716441869735718
# epoch 26, mini-batch 80.0/117.506 loss is 0.6425853371620178
# epoch 26, mini-batch 100.0/117.506 loss is 0.7173431515693665
# epoch 26: train_accuracy is 84.8, test_accuracy is 80.8
# epoch 27, mini-batch 0.0/117.506 loss is 0.7261248826980591
# epoch 27, mini-batch 20.0/117.506 loss is 0.7119630575180054
# epoch 27, mini-batch 40.0/117.506 loss is 0.6641803979873657
# epoch 27, mini-batch 60.0/117.506 loss is 0.5943109393119812
# epoch 27, mini-batch 80.0/117.506 loss is 0.6504022479057312
# epoch 27, mini-batch 100.0/117.506 loss is 0.6475363969802856
# epoch 27: train_accuracy is 85.1, test_accuracy is 81.2
# epoch 28, mini-batch 0.0/117.506 loss is 0.7438457608222961
# epoch 28, mini-batch 20.0/117.506 loss is 0.6452172994613647
# epoch 28, mini-batch 40.0/117.506 loss is 0.5882996916770935
# epoch 28, mini-batch 60.0/117.506 loss is 0.5860297083854675
# epoch 28, mini-batch 80.0/117.506 loss is 0.5976229906082153
# epoch 28, mini-batch 100.0/117.506 loss is 0.6377982497215271
# epoch 28: train_accuracy is 85.3, test_accuracy is 80.7
# epoch 29, mini-batch 0.0/117.506 loss is 0.7108297348022461
# epoch 29, mini-batch 20.0/117.506 loss is 0.6230103969573975
# epoch 29, mini-batch 40.0/117.506 loss is 0.6059281826019287
# epoch 29, mini-batch 60.0/117.506 loss is 0.5389213562011719
# epoch 29, mini-batch 80.0/117.506 loss is 0.5950161218643188
# epoch 29, mini-batch 100.0/117.506 loss is 0.6998715996742249
# epoch 29: train_accuracy is 86.3, test_accuracy is 81.7
# epoch 30, mini-batch 0.0/117.506 loss is 0.6343633532524109
# epoch 30, mini-batch 20.0/117.506 loss is 0.6304267644882202
# epoch 30, mini-batch 40.0/117.506 loss is 0.6363410949707031
# epoch 30, mini-batch 60.0/117.506 loss is 0.524500846862793
# epoch 30, mini-batch 80.0/117.506 loss is 0.591317892074585
# epoch 30, mini-batch 100.0/117.506 loss is 0.61139315366745
# epoch 30: train_accuracy is 85.5, test_accuracy is 80.1
# epoch 31, mini-batch 0.0/117.506 loss is 0.6734326481819153
# epoch 31, mini-batch 20.0/117.506 loss is 0.637310266494751
# epoch 31, mini-batch 40.0/117.506 loss is 0.6187596321105957
# epoch 31, mini-batch 60.0/117.506 loss is 0.5447234511375427
# epoch 31, mini-batch 80.0/117.506 loss is 0.6219021081924438
# epoch 31, mini-batch 100.0/117.506 loss is 0.6216058731079102
# epoch 31: train_accuracy is 86.3, test_accuracy is 80.3
# epoch 32, mini-batch 0.0/117.506 loss is 0.7015178203582764
# epoch 32, mini-batch 20.0/117.506 loss is 0.6209536194801331
# epoch 32, mini-batch 40.0/117.506 loss is 0.5671197772026062
# epoch 32, mini-batch 60.0/117.506 loss is 0.5570945739746094
# epoch 32, mini-batch 80.0/117.506 loss is 0.6378671526908875
# epoch 32, mini-batch 100.0/117.506 loss is 0.6381508111953735
# epoch 32: train_accuracy is 87.1, test_accuracy is 81.0
# epoch 33, mini-batch 0.0/117.506 loss is 0.623266339302063
# epoch 33, mini-batch 20.0/117.506 loss is 0.6369889974594116
# epoch 33, mini-batch 40.0/117.506 loss is 0.5685615539550781
# epoch 33, mini-batch 60.0/117.506 loss is 0.523678719997406
# epoch 33, mini-batch 80.0/117.506 loss is 0.5013241171836853
# epoch 33, mini-batch 100.0/117.506 loss is 0.5969170928001404
# epoch 33: train_accuracy is 86.7, test_accuracy is 81.0
# epoch 34, mini-batch 0.0/117.506 loss is 0.6204955577850342
# epoch 34, mini-batch 20.0/117.506 loss is 0.6089344620704651
# epoch 34, mini-batch 40.0/117.506 loss is 0.5570975542068481
# epoch 34, mini-batch 60.0/117.506 loss is 0.6056662797927856
# epoch 34, mini-batch 80.0/117.506 loss is 0.5338876843452454
# epoch 34, mini-batch 100.0/117.506 loss is 0.5715448260307312
# epoch 34: train_accuracy is 87.4, test_accuracy is 80.1
# epoch 35, mini-batch 0.0/117.506 loss is 0.6417674422264099
# epoch 35, mini-batch 20.0/117.506 loss is 0.6263952851295471
# epoch 35, mini-batch 40.0/117.506 loss is 0.5629364252090454
# epoch 35, mini-batch 60.0/117.506 loss is 0.5288872718811035
# epoch 35, mini-batch 80.0/117.506 loss is 0.5774441957473755
# epoch 35, mini-batch 100.0/117.506 loss is 0.6136828064918518
# epoch 35: train_accuracy is 86.9, test_accuracy is 81.4
# epoch 36, mini-batch 0.0/117.506 loss is 0.6386570930480957
# epoch 36, mini-batch 20.0/117.506 loss is 0.6144419312477112
# epoch 36, mini-batch 40.0/117.506 loss is 0.5800620317459106
# epoch 36, mini-batch 60.0/117.506 loss is 0.5453263521194458
# epoch 36, mini-batch 80.0/117.506 loss is 0.5701998472213745
# epoch 36, mini-batch 100.0/117.506 loss is 0.5708603858947754
# epoch 36: train_accuracy is 88.1, test_accuracy is 82.2
# epoch 37, mini-batch 0.0/117.506 loss is 0.5775222778320312
# epoch 37, mini-batch 20.0/117.506 loss is 0.6321297883987427
# epoch 37, mini-batch 40.0/117.506 loss is 0.5503340363502502
# epoch 37, mini-batch 60.0/117.506 loss is 0.5000389218330383
# epoch 37, mini-batch 80.0/117.506 loss is 0.5139884352684021
# epoch 37, mini-batch 100.0/117.506 loss is 0.569279134273529
# epoch 37: train_accuracy is 88.1, test_accuracy is 80.0
# epoch 38, mini-batch 0.0/117.506 loss is 0.5498744249343872
# epoch 38, mini-batch 20.0/117.506 loss is 0.6196786761283875
# epoch 38, mini-batch 40.0/117.506 loss is 0.5892866253852844
# epoch 38, mini-batch 60.0/117.506 loss is 0.5313936471939087
# epoch 38, mini-batch 80.0/117.506 loss is 0.5459909439086914
# epoch 38, mini-batch 100.0/117.506 loss is 0.5608330965042114
# epoch 38: train_accuracy is 87.9, test_accuracy is 81.8
# epoch 39, mini-batch 0.0/117.506 loss is 0.6040171384811401
# epoch 39, mini-batch 20.0/117.506 loss is 0.5756945013999939
# epoch 39, mini-batch 40.0/117.506 loss is 0.5644716024398804
# epoch 39, mini-batch 60.0/117.506 loss is 0.5077829957008362
# epoch 39, mini-batch 80.0/117.506 loss is 0.5456872582435608
# epoch 39, mini-batch 100.0/117.506 loss is 0.5645912289619446
# epoch 39: train_accuracy is 88.5, test_accuracy is 81.4

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(range(num_epochs), train_accuracies, label="train")
ax.plot(range(num_epochs), test_accuracies, label="test")
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy per Epoch')
ax.legend()
plt.show()

# %%
out = model(X_test[76][None, :, :, :])
_, predicted = torch.max(out, 1)
print(predicted)
print(y_test_int[76])
# Out:
# tensor([102], device='privateuseone:0')
# tensor(309., device='privateuseone:0')

# %%
from torch import save

model = model.to("cpu")
with open('model_state.pt', 'wb') as f: 
        save(model.state_dict(), f)

# %%
from torch import load

with open('model_state.pt', 'rb') as f: 
        model.load_state_dict(load(f))
